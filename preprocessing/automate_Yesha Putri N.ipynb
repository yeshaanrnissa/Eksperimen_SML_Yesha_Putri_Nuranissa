# %%
import pandas as pd
from preprocessing import preprocess_data
from joblib import load
import numpy as np
 
# Memuat dataset
data = pd.read_csv("titanic.csv")
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
X_train, X_test, y_train, y_test = preprocess_data(data, 'Survived', 'preprocessor_pipeline.joblib', 'data.csv')
# Out:
# Nama kolom berhasil disimpan ke: data.csv

# %%
def inference(new_data, pipeline_path):
    pipeline = load(pipeline_path)
    transformed_data = pipeline.transform(new_data)
    return transformed_data

# %%
feature_columns = pd.read_csv("data.csv").columns.tolist()

new_data = pd.DataFrame([{
    "PassengerId": 99,
    "Pclass": 3,
    "Name": "Dummy Name",
    "Sex": "male",
    "Age": 22,
    "SibSp": 1,
    "Parch": 0,
    "Ticket": "A/5 21171",
    "Fare": 7.35,
    "Cabin": None,
    "Embarked": "S"
}], columns=feature_columns)

# Transform data baru
transformed_data = inference(new_data, "preprocessor_pipeline.joblib")

print("Data baru (raw):")
print(new_data)

print("\nData baru setelah preprocessing:")
print(transformed_data)
# Out:
# Data baru (raw):
#    PassengerId  Pclass        Name   Sex  Age  SibSp  Parch     Ticket  Fare  \
# 0           99       3  Dummy Name  male   22      1      0  A/5 21171  7.35
#
#   Cabin Embarked
# 0  None        S
#
# Data baru setelah preprocessing:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 9 stored elements and shape (1, 1237)>
#   Coords	Values
#   (0, 0)	-1.3378585790765118
#   (0, 1)	0.803267115399189
#   (0, 2)	-0.5574797528273849
#   (0, 3)	0.3486869415553448
#   (0, 4)	-0.4793270558753074
#   (0, 5)	-0.4803384519848686
#   (0, 630)	1.0
#   (0, 1015)	1.0
#   (0, 1235)	1.0
